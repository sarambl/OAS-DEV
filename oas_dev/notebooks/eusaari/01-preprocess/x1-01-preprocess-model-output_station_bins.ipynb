# %% [markdown]
# ### Imports

# %%
from sectional_v2.util.Nd.sizedist_class_v2.SizedistributionBins import SizedistributionStationBins
from sectional_v2.util.collocate.collocateLONLAToutput import CollocateLONLATout
from sectional_v2.constants import sized_varListNorESM, list_sized_vars_nonsec, list_sized_vars_noresm
#from useful_scit.util import log
import useful_scit.util.log as log
log.ger.setLevel(log.log.INFO)
# Out:
# /home/ubuntu/mnts/nird/projects//Output_data_OAS-DEV/
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Settings

# %%
nr_of_bins = 5
maxDiameter = 39.6  #    23.6 #e-9
minDiameter = 5.0  # e-9
history_field='.h1.'
cases_sec = ['SECTv11_noresm2_NFHIST']#'SECTv11_ctrl_fbvoc']#'SECTv11_ctrl']#,'SECTv11_ctrl_fbvoc']#'SECTv11_ctrl']
cases_orig =[]#'noSECTv11_ctrl_fbvoc'] #/no SECTv11_ctrl
from_t = '2008-01-01'
to_t = '2009-01-01'

# %% [markdown]
# ## Compute collocated datasets from latlon specified output

# %%
for case_name in cases_sec:
    varlist = list_sized_vars_noresm
    c = CollocateLONLATout(case_name, from_t, to_t,
                       True,
                       'hour',
                       history_field=history_field)
    if c.check_if_load_raw_necessary(varlist ):
        a = c.make_station_data_all()
    else:
        print('UUUPS')
for case_name in cases_orig:
    varlist = list_sized_vars_nonsec
    c = CollocateLONLATout(case_name, from_t, to_t,
                           False,
                           'hour',
                           history_field=history_field)

    if c.check_if_load_raw_necessary(varlist ):
        a = c.make_station_data_all()
    else:
        print('IIIIP')
# Out:
# 2020-04-01 12:57:49,106 useful_scit  INFO     Path file list:
# 2020-04-01 12:57:49,106 useful_scit  INFO     Path file list:
# 2020-04-01 12:57:49,108 useful_scit  INFO     ['/home/ubuntu/mnts/nird/projects/model_output/archive/noSECTv11_ctrl_fbvoc/atm/hist/noSECTv11_ctrl_fbvoc.cam.h1.2008-01-01-00000.nc', '/home/ubuntu/mnts/nird/projects/model_output/archive/noSECTv11_ctrl_fbvoc/atm/hist/noSECTv11_ctrl_fbvoc.cam.h1.2008-01-02-00000.nc', '/home/ubuntu/mnts/nird/projects/model_output/archive/noSECTv11_ctrl_fbvoc/atm/hist/noSECTv11_ctrl_fbvoc.cam.h1.2008-01-03-00000.nc', '/home/ubuntu/mnts/nird/projects/model_output/archive/noSECTv11_ctrl_fbvoc/atm/hist/noSECTv11_ctrl_fbvoc.cam.h1.2008-01-04-00000.nc']
# 2020-04-01 12:57:49,108 useful_scit  INFO     ['/home/ubuntu/mnts/nird/projects/model_output/archive/noSECTv11_ctrl_fbvoc/atm/hist/noSECTv11_ctrl_fbvoc.cam.h1.2008-01-01-00000.nc', '/home/ubuntu/mnts/nird/projects/model_output/archive/noSECTv11_ctrl_fbvoc/atm/hist/noSECTv11_ctrl_fbvoc.cam.h1.2008-01-02-00000.nc', '/home/ubuntu/mnts/nird/projects/model_output/archive/noSECTv11_ctrl_fbvoc/atm/hist/noSECTv11_ctrl_fbvoc.cam.h1.2008-01-03-00000.nc', '/home/ubuntu/mnts/nird/projects/model_output/archive/noSECTv11_ctrl_fbvoc/atm/hist/noSECTv11_ctrl_fbvoc.cam.h1.2008-01-04-00000.nc']
# 2020-04-01 12:58:02,589 useful_scit  INFO     Returning raw dataset from import_fields_cr_v2.py
# Returning raw dataset
# 2020-04-01 12:58:02,589 useful_scit  INFO     Returning raw dataset from import_fields_cr_v2.py
# making station dataset for CCN4
# making other dataset
#                                                                 ASP  \
# Station name                                              Aspvreten
# Country                                                          SE
# Coordinates, altitude                     58 ◦ 48 N,17 ◦ 23 E, 30 m
# Categorya                                                       NaN
# Instrument                                                     DMPS
# Reference                                      Tunved et al. (2004)
# Region                                            Nordic and Baltic
# Altitude category      Low altitude sites (less than 1000 m a.s.l.)
# lat                                                            58.8
# lon                                                17.3833333333333
# altitude                                                       30 m
# noresm_input_format                                   17.38e_58.80n
# noresm_output_format                          LON_17.38e_LAT_58.80n
# Alternative_code                                                ASP
#
#                                                                 BIR  \
# Station name                                             Birkenes b
# Country                                                          NO
# Coordinates, altitude                     58 ◦ 23 N,8 ◦ 15 E, 190 m
# Categorya                                                       2.0
# Instrument                                                     DMPS
# Reference                                     Amunsen et al. (1992)
# Region                                            Nordic and Baltic
# Altitude category      Low altitude sites (less than 1000 m a.s.l.)
# lat                                              58.383333333333304
# lon                                                            8.25
# altitude                                                      190 m
# noresm_input_format                                    8.25e_58.38n
# noresm_output_format                           LON_8.25e_LAT_58.38n
# Alternative_code                                                BIR
#
#                                                                 PAL  \
# Station name                                                 Pallas
# Country                                                          FI
# Coordinates, altitude                     67 ◦ 58 N,24 ◦ 7 E, 560 m
# Categorya                                                       NaN
# Instrument                                                     DMPS
# Reference                                  Lihavainen et al. (2008)
# Region                                            Nordic and Baltic
# Altitude category      Low altitude sites (less than 1000 m a.s.l.)
# lat                                                67.9666666666667
# lon                                                24.1166666666667
# altitude                                                      560 m
# noresm_input_format                                   24.12e_67.97n
# noresm_output_format                          LON_24.12e_LAT_67.97n
# Alternative_code                                                PAL
#
#                                                                 PLA  \
# Station name                                                 Preila
# Country                                                          LT
# Coordinates, altitude                       55 ◦ 55 N,21 ◦ 0 E, 5 m
# Categorya                                                       6.0
# Instrument                                                     SMPS
# Reference                                   Ulevicius et al. (2010)
# Region                                            Nordic and Baltic
# Altitude category      Low altitude sites (less than 1000 m a.s.l.)
# lat                                                55.9166666666667
# lon                                                            21.0
# altitude                                                        5 m
# noresm_input_format                                   21.00e_55.92n
# noresm_output_format                          LON_21.00e_LAT_55.92n
# Alternative_code                                                PLA
#
#                                                                 SMR  \
# Station name                                               SMEAR II
# Country                                                          FI
# Coordinates, altitude                    61 ◦ 51 N,24 ◦ 17 E, 181 m
# Categorya                                                       NaN
# Instrument                                                     DMPS
# Reference                                   Hari and Kulmala (2005)
# Region                                            Nordic and Baltic
# Altitude category      Low altitude sites (less than 1000 m a.s.l.)
# lat                                                           61.85
# lon                                              24.283333333333303
# altitude                                                      181 m
# noresm_input_format                                   24.28e_61.85n
# noresm_output_format                          LON_24.28e_LAT_61.85n
# Alternative_code                                                SMR
#
#                                                                 VHL  \
# Station name                                               Vavihill
# Country                                                          SE
# Coordinates, altitude                      56 ◦ 1 N,13 ◦ 9 E, 172 m
# Categorya                                                       NaN
# Instrument                                                     DMPS
# Reference                                 Kristensson et al. (2008)
# Region                                            Nordic and Baltic
# Altitude category      Low altitude sites (less than 1000 m a.s.l.)
# lat                                                56.0166666666667
# lon                                                           13.15
# altitude                                                      172 m
# noresm_input_format                                   13.15e_56.02n
# noresm_output_format                          LON_13.15e_LAT_56.02n
# Alternative_code                                                VHL
#
#                                                                 BOS  \
# Station name                                                  Bösel
# Country                                                          DE
# Coordinates, altitude                       53 ◦ 0 N,7 ◦ 57 E, 16 m
# Categorya                                                       NaN
# Instrument                                                     SMPS
# Reference                                    Birmili et al. (2009a)
# Region                                               Central Europe
# Altitude category      Low altitude sites (less than 1000 m a.s.l.)
# lat                                                            53.0
# lon                                                            7.95
# altitude                                                       16 m
# noresm_input_format                                    7.95e_53.00n
# noresm_output_format                           LON_7.95e_LAT_53.00n
# Alternative_code                                                BOE
#
#                                                                 KPO  \
# Station name                                               K-Puszta
# Country                                                          HU
# Coordinates, altitude                    46 ◦ 58 N,19 ◦ 33 E, 125 m
# Categorya                                                       1.0
# Instrument                                                     DMPS
# Reference                                        Kiss et al. (2002)
# Region                                               Central Europe
# Altitude category      Low altitude sites (less than 1000 m a.s.l.)
# lat                                                46.9666666666667
# lon                                                           19.55
# altitude                                                      125 m
# noresm_input_format                                   19.55e_46.97n
# noresm_output_format                          LON_19.55e_LAT_46.97n
# Alternative_code                                                KPO
#
#                                                                 MPZ  \
# Station name                                                Melpitz
# Country                                                          DE
# Coordinates, altitude                     51 ◦ 32 N,12 ◦ 54 E, 87 m
# Categorya                                                       NaN
# Instrument                                                     DMPS
# Reference                                      Engler et al. (2007)
# Region                                               Central Europe
# Altitude category      Low altitude sites (less than 1000 m a.s.l.)
# lat                                                51.5333333333333
# lon                                                            12.9
# altitude                                                       87 m
# noresm_input_format                                   12.90e_51.53n
# noresm_output_format                          LON_12.90e_LAT_51.53n
# Alternative_code                                                MPZ
#
#                                                                OBK  ...  \
# Station name                                              Kosetice  ...
# Country                                                         CZ  ...
# Coordinates, altitude                    49 ◦ 35 N,15 ◦ 5 E, 534 m  ...
# Categorya                                                      1.0  ...
# Instrument                                                    SMPS  ...
# Reference                             C̆ervenková and Ván̆a (2010)  ...
# Region                                              Central Europe  ...
# Altitude category      Low altitude sites(less than 1000 m a.s.l.)  ...
# lat                                               49.5833333333333  ...
# lon                                             15.083333333333302  ...
# altitude                                                     534 m  ...
# noresm_input_format                                  15.08e_49.58n  ...
# noresm_output_format                         LON_15.08e_LAT_49.58n  ...
# Alternative_code                                               OBK  ...
#
#                                                                 MHD  \
# Station name                                              Mace Head
# Country                                                          IE
# Coordinates, altitude                       53 ◦ 19 N,9 ◦ 53 W, 5 m
# Categorya                                                       5.0
# Instrument                                                     SMPS
# Reference                                    Jennings et al. (1991)
# Region                                               Western Europe
# Altitude category      Low altitude sites (less than 1000 m a.s.l.)
# lat                                                53.3166666666667
# lon                                                9.88333333333333
# altitude                                                        5 m
# noresm_input_format                                    9.88e_53.32n
# noresm_output_format                           LON_9.88e_LAT_53.32n
# Alternative_code                                                MHD
#
#                                                                 FKL  \
# Station name                                              Finokalia
# Country                                                          GR
# Coordinates, altitude                    35 ◦ 20 N,25 ◦ 40 E, 250 m
# Categorya                                                       2.0
# Instrument                                                     SMPS
# Reference                                Mihalopoulos et al. (1997)
# Region                                                Mediterranean
# Altitude category      Low altitude sites (less than 1000 m a.s.l.)
# lat                                                35.3333333333333
# lon                                                25.6666666666667
# altitude                                                      250 m
# noresm_input_format                                   25.67e_35.33n
# noresm_output_format                          LON_25.67e_LAT_35.33n
# Alternative_code                                                FKL
#
#                                                                 JRC  \
# Station name                                              JRC-Ispra
# Country                                                          IT
# Coordinates, altitude                     45 ◦ 49 N,8 ◦ 38 E, 209 m
# Categorya                                                       3.0
# Instrument                                                     DMPS
# Reference                                    Gruening et al. (2009)
# Region                                                Mediterranean
# Altitude category      Low altitude sites (less than 1000 m a.s.l.)
# lat                                                45.8166666666667
# lon                                                8.63333333333333
# altitude                                                      209 m
# noresm_input_format                                    8.63e_45.82n
# noresm_output_format                           LON_8.63e_LAT_45.82n
# Alternative_code                                                ISP
#
#                                                                 ZEP  \
# Station name                                               Zeppelin
# Country                                                          NO
# Coordinates, altitude                    78 ◦ 55 N,11 ◦ 54 E, 474 m
# Categorya                                                       NaN
# Instrument                                                     DMPS
# Reference                                       Ström et al. (2003)
# Region                                                       Arctic
# Altitude category      Low altitude sites (less than 1000 m a.s.l.)
# lat                                                78.9166666666667
# lon                                                            11.9
# altitude                                                      474 m
# noresm_input_format                                   11.90e_78.92n
# noresm_output_format                          LON_11.90e_LAT_78.92n
# Alternative_code                                                ZEP
#
#                                                             PDD  \
# Station name                                        Puy de Dôme
# Country                                                      FR
# Coordinates, altitude                45 ◦ 46 N,2 ◦ 57 E, 1465 m
# Categorya                                                   4.0
# Instrument                                                 SMPS
# Reference                                  Venzac et al. (2009)
# Region                                           Western Europe
# Altitude category      High altitude sites (over 1000 m a.s.l.)
# lat                                            45.7666666666667
# lon                                                        2.95
# altitude                                                 1465 m
# noresm_input_format                                2.95e_45.77n
# noresm_output_format                       LON_2.95e_LAT_45.77n
# Alternative_code                                            PDD
#
#                                                             SSL  \
# Station name                                       Schauinsland
# Country                                                      DE
# Coordinates, altitude                47 ◦ 55 N,7 ◦ 55 E, 1210 m
# Categorya                                                   1.0
# Instrument                                                 SMPS
# Reference                                Birmili et al. (2009a)
# Region                                           Central Europe
# Altitude category      High altitude sites (over 1000 m a.s.l.)
# lat                                            47.9166666666667
# lon                                            7.91666666666667
# altitude                                                 1210 m
# noresm_input_format                                7.92e_47.92n
# noresm_output_format                       LON_7.92e_LAT_47.92n
# Alternative_code                                            SCH
#
#                                                             ZSF  \
# Station name                                          Zugspitze
# Country                                                      DE
# Coordinates, altitude               47 ◦ 25 N,10 ◦ 59 E, 2650 m
# Categorya                                                   4.0
# Instrument                                                 SMPS
# Reference                                Birmili et al. (2009a)
# Region                                           Central Europe
# Altitude category      High altitude sites (over 1000 m a.s.l.)
# lat                                            47.4166666666667
# lon                                          10.983333333333302
# altitude                                                 2650 m
# noresm_input_format                               10.98e_47.42n
# noresm_output_format                      LON_10.98e_LAT_47.42n
# Alternative_code                                            ZSF
#
#                                                             JFJ  \
# Station name                                       Jungfraujoch
# Country                                                      CH
# Coordinates, altitude                46 ◦ 32 N,7 ◦ 59 E, 3580 m
# Categorya                                                   2.0
# Instrument                                                 SMPS
# Reference                                 Jurányi et al. (2011)
# Region                                           Central Europe
# Altitude category      High altitude sites (over 1000 m a.s.l.)
# lat                                            46.5333333333333
# lon                                            7.98333333333333
# altitude                                                 3580 m
# noresm_input_format                                7.98e_46.53n
# noresm_output_format                       LON_7.98e_LAT_46.53n
# Alternative_code                                            JFJ
#
#                                                             BEO  \
# Station name                                       BEO Moussala
# Country                                                      BG
# Coordinates, altitude               42 ◦ 10 N,23 ◦ 35 E, 2971 m
# Categorya                                                   NaN
# Instrument                                                 SMPS
# Reference                                 Nojarov et al. (2009)
# Region                                                  Balkans
# Altitude category      High altitude sites (over 1000 m a.s.l.)
# lat                                            42.1666666666667
# lon                                            23.5833333333333
# altitude                                                 2971 m
# noresm_input_format                               23.58e_42.17n
# noresm_output_format                      LON_23.58e_LAT_42.17n
# Alternative_code                                            BEO
#
#                                                             CMN
# Station name                                       Monte Cimone
# Country                                                      IT
# Coordinates, altitude               44 ◦ 11 N,10 ◦ 41 E, 2165 m
# Categorya                                                   4.0
# Instrument                                                 DMPS
# Reference                                Marinoni et al. (2008)
# Region                                            Mediterranean
# Altitude category      High altitude sites (over 1000 m a.s.l.)
# lat                                            44.1833333333333
# lon                                            10.6833333333333
# altitude                                                 2165 m
# noresm_input_format                               10.68e_44.18n
# noresm_output_format                      LON_10.68e_LAT_44.18n
# Alternative_code                                            CMN
#
# [14 rows x 24 columns]
# Saving CCN4 to /home/ubuntu/mnts/nird/projects//Output_data_OAS-DEV//collocated_ds//NorESM/noSECTv11_ctrl_fbvoc/CCN4_noSECTv11_ctrl_fbvoc_2008-01-01_2008-01-04_hour_locations.nc
# making station dataset for CCN6
# making other dataset
# station                                                         ASP  \
# Station name                                              Aspvreten
# Country                                                          SE
# Coordinates, altitude                     58 ◦ 48 N,17 ◦ 23 E, 30 m
# Categorya                                                       NaN
# Instrument                                                     DMPS
# Reference                                      Tunved et al. (2004)
# Region                                            Nordic and Baltic
# Altitude category      Low altitude sites (less than 1000 m a.s.l.)
# lat                                                            58.8
# lon                                                17.3833333333333
# altitude                                                       30 m
# noresm_input_format                                   17.38e_58.80n
# noresm_output_format                          LON_17.38e_LAT_58.80n
# Alternative_code                                                ASP
#
# station                                                         BIR  \
# Station name                                             Birkenes b
# Country                                                          NO
# Coordinates, altitude                     58 ◦ 23 N,8 ◦ 15 E, 190 m
# Categorya                                                       2.0
# Instrument                                                     DMPS
# Reference                                     Amunsen et al. (1992)
# Region                                            Nordic and Baltic
# Altitude category      Low altitude sites (less than 1000 m a.s.l.)
# lat                                              58.383333333333304
# lon                                                            8.25
# altitude                                                      190 m
# noresm_input_format                                    8.25e_58.38n
# noresm_output_format                           LON_8.25e_LAT_58.38n
# Alternative_code                                                BIR
#
# station                                                         PAL  \
# Station name                                                 Pallas
# Country                                                          FI
# Coordinates, altitude                     67 ◦ 58 N,24 ◦ 7 E, 560 m
# Categorya                                                       NaN
# Instrument                                                     DMPS
# Reference                                  Lihavainen et al. (2008)
# Region                                            Nordic and Baltic
# Altitude category      Low altitude sites (less than 1000 m a.s.l.)
# lat                                                67.9666666666667
# lon                                                24.1166666666667
# altitude                                                      560 m
# noresm_input_format                                   24.12e_67.97n
# noresm_output_format                          LON_24.12e_LAT_67.97n
# Alternative_code                                                PAL
#
# station                                                         PLA  \
# Station name                                                 Preila
# Country                                                          LT
# Coordinates, altitude                       55 ◦ 55 N,21 ◦ 0 E, 5 m
# Categorya                                                       6.0
# Instrument                                                     SMPS
# Reference                                   Ulevicius et al. (2010)
# Region                                            Nordic and Baltic
# Altitude category      Low altitude sites (less than 1000 m a.s.l.)
# lat                                                55.9166666666667
# lon                                                            21.0
# altitude                                                        5 m
# noresm_input_format                                   21.00e_55.92n
# noresm_output_format                          LON_21.00e_LAT_55.92n
# Alternative_code                                                PLA
#
# station                                                         SMR  \
# Station name                                               SMEAR II
# Country                                                          FI
# Coordinates, altitude                    61 ◦ 51 N,24 ◦ 17 E, 181 m
# Categorya                                                       NaN
# Instrument                                                     DMPS
# Reference                                   Hari and Kulmala (2005)
# Region                                            Nordic and Baltic
# Altitude category      Low altitude sites (less than 1000 m a.s.l.)
# lat                                                           61.85
# lon                                              24.283333333333303
# altitude                                                      181 m
# noresm_input_format                                   24.28e_61.85n
# noresm_output_format                          LON_24.28e_LAT_61.85n
# Alternative_code                                                SMR
#
# station                                                         VHL  \
# Station name                                               Vavihill
# Country                                                          SE
# Coordinates, altitude                      56 ◦ 1 N,13 ◦ 9 E, 172 m
# Categorya                                                       NaN
# Instrument                                                     DMPS
# Reference                                 Kristensson et al. (2008)
# Region                                            Nordic and Baltic
# Altitude category      Low altitude sites (less than 1000 m a.s.l.)
# lat                                                56.0166666666667
# lon                                                           13.15
# altitude                                                      172 m
# noresm_input_format                                   13.15e_56.02n
# noresm_output_format                          LON_13.15e_LAT_56.02n
# Alternative_code                                                VHL
#
# station                                                         BOS  \
# Station name                                                  Bösel
# Country                                                          DE
# Coordinates, altitude                       53 ◦ 0 N,7 ◦ 57 E, 16 m
# Categorya                                                       NaN
# Instrument                                                     SMPS
# Reference                                    Birmili et al. (2009a)
# Region                                               Central Europe
# Altitude category      Low altitude sites (less than 1000 m a.s.l.)
# lat                                                            53.0
# lon                                                            7.95
# altitude                                                       16 m
# noresm_input_format                                    7.95e_53.00n
# noresm_output_format                           LON_7.95e_LAT_53.00n
# Alternative_code                                                BOE
#
# station                                                         KPO  \
# Station name                                               K-Puszta
# Country                                                          HU
# Coordinates, altitude                    46 ◦ 58 N,19 ◦ 33 E, 125 m
# Categorya                                                       1.0
# Instrument                                                     DMPS
# Reference                                        Kiss et al. (2002)
# Region                                               Central Europe
# Altitude category      Low altitude sites (less than 1000 m a.s.l.)
# lat                                                46.9666666666667
# lon                                                           19.55
# altitude                                                      125 m
# noresm_input_format                                   19.55e_46.97n
# noresm_output_format                          LON_19.55e_LAT_46.97n
# Alternative_code                                                KPO
#
# station                                                         MPZ  \
# Station name                                                Melpitz
# Country                                                          DE
# Coordinates, altitude                     51 ◦ 32 N,12 ◦ 54 E, 87 m
# Categorya                                                       NaN
# Instrument                                                     DMPS
# Reference                                      Engler et al. (2007)
# Region                                               Central Europe
# Altitude category      Low altitude sites (less than 1000 m a.s.l.)
# lat                                                51.5333333333333
# lon                                                            12.9
# altitude                                                       87 m
# noresm_input_format                                   12.90e_51.53n
# noresm_output_format                          LON_12.90e_LAT_51.53n
# Alternative_code                                                MPZ
#
# station                                                        OBK  ...  \
# Station name                                              Kosetice  ...
# Country                                                         CZ  ...
# Coordinates, altitude                    49 ◦ 35 N,15 ◦ 5 E, 534 m  ...
# Categorya                                                      1.0  ...
# Instrument                                                    SMPS  ...
# Reference                             C̆ervenková and Ván̆a (2010)  ...
# Region                                              Central Europe  ...
# Altitude category      Low altitude sites(less than 1000 m a.s.l.)  ...
# lat                                               49.5833333333333  ...
# lon                                             15.083333333333302  ...
# altitude                                                     534 m  ...
# noresm_input_format                                  15.08e_49.58n  ...
# noresm_output_format                         LON_15.08e_LAT_49.58n  ...
# Alternative_code                                               OBK  ...
#
# station                                                         MHD  \
# Station name                                              Mace Head
# Country                                                          IE
# Coordinates, altitude                       53 ◦ 19 N,9 ◦ 53 W, 5 m
# Categorya                                                       5.0
# Instrument                                                     SMPS
# Reference                                    Jennings et al. (1991)
# Region                                               Western Europe
# Altitude category      Low altitude sites (less than 1000 m a.s.l.)
# lat                                                53.3166666666667
# lon                                                9.88333333333333
# altitude                                                        5 m
# noresm_input_format                                    9.88e_53.32n
# noresm_output_format                           LON_9.88e_LAT_53.32n
# Alternative_code                                                MHD
#
# station                                                         FKL  \
# Station name                                              Finokalia
# Country                                                          GR
# Coordinates, altitude                    35 ◦ 20 N,25 ◦ 40 E, 250 m
# Categorya                                                       2.0
# Instrument                                                     SMPS
# Reference                                Mihalopoulos et al. (1997)
# Region                                                Mediterranean
# Altitude category      Low altitude sites (less than 1000 m a.s.l.)
# lat                                                35.3333333333333
# lon                                                25.6666666666667
# altitude                                                      250 m
# noresm_input_format                                   25.67e_35.33n
# noresm_output_format                          LON_25.67e_LAT_35.33n
# Alternative_code                                                FKL
#
# station                                                         JRC  \
# Station name                                              JRC-Ispra
# Country                                                          IT
# Coordinates, altitude                     45 ◦ 49 N,8 ◦ 38 E, 209 m
# Categorya                                                       3.0
# Instrument                                                     DMPS
# Reference                                    Gruening et al. (2009)
# Region                                                Mediterranean
# Altitude category      Low altitude sites (less than 1000 m a.s.l.)
# lat                                                45.8166666666667
# lon                                                8.63333333333333
# altitude                                                      209 m
# noresm_input_format                                    8.63e_45.82n
# noresm_output_format                           LON_8.63e_LAT_45.82n
# Alternative_code                                                ISP
#
# station                                                         ZEP  \
# Station name                                               Zeppelin
# Country                                                          NO
# Coordinates, altitude                    78 ◦ 55 N,11 ◦ 54 E, 474 m
# Categorya                                                       NaN
# Instrument                                                     DMPS
# Reference                                       Ström et al. (2003)
# Region                                                       Arctic
# Altitude category      Low altitude sites (less than 1000 m a.s.l.)
# lat                                                78.9166666666667
# lon                                                            11.9
# altitude                                                      474 m
# noresm_input_format                                   11.90e_78.92n
# noresm_output_format                          LON_11.90e_LAT_78.92n
# Alternative_code                                                ZEP
#
# station                                                     PDD  \
# Station name                                        Puy de Dôme
# Country                                                      FR
# Coordinates, altitude                45 ◦ 46 N,2 ◦ 57 E, 1465 m
# Categorya                                                   4.0
# Instrument                                                 SMPS
# Reference                                  Venzac et al. (2009)
# Region                                           Western Europe
# Altitude category      High altitude sites (over 1000 m a.s.l.)
# lat                                            45.7666666666667
# lon                                                        2.95
# altitude                                                 1465 m
# noresm_input_format                                2.95e_45.77n
# noresm_output_format                       LON_2.95e_LAT_45.77n
# Alternative_code                                            PDD
#
# station                                                     SSL  \
# Station name                                       Schauinsland
# Country                                                      DE
# Coordinates, altitude                47 ◦ 55 N,7 ◦ 55 E, 1210 m
# Categorya                                                   1.0
# Instrument                                                 SMPS
# Reference                                Birmili et al. (2009a)
# Region                                           Central Europe
# Altitude category      High altitude sites (over 1000 m a.s.l.)
# lat                                            47.9166666666667
# lon                                            7.91666666666667
# altitude                                                 1210 m
# noresm_input_format                                7.92e_47.92n
# noresm_output_format                       LON_7.92e_LAT_47.92n
# Alternative_code                                            SCH
#
# station                                                     ZSF  \
# Station name                                          Zugspitze
# Country                                                      DE
# Coordinates, altitude               47 ◦ 25 N,10 ◦ 59 E, 2650 m
# Categorya                                                   4.0
# Instrument                                                 SMPS
# Reference                                Birmili et al. (2009a)
# Region                                           Central Europe
# Altitude category      High altitude sites (over 1000 m a.s.l.)
# lat                                            47.4166666666667
# lon                                          10.983333333333302
# altitude                                                 2650 m
# noresm_input_format                               10.98e_47.42n
# noresm_output_format                      LON_10.98e_LAT_47.42n
# Alternative_code                                            ZSF
#
# station                                                     JFJ  \
# Station name                                       Jungfraujoch
# Country                                                      CH
# Coordinates, altitude                46 ◦ 32 N,7 ◦ 59 E, 3580 m
# Categorya                                                   2.0
# Instrument                                                 SMPS
# Reference                                 Jurányi et al. (2011)
# Region                                           Central Europe
# Altitude category      High altitude sites (over 1000 m a.s.l.)
# lat                                            46.5333333333333
# lon                                            7.98333333333333
# altitude                                                 3580 m
# noresm_input_format                                7.98e_46.53n
# noresm_output_format                       LON_7.98e_LAT_46.53n
# Alternative_code                                            JFJ
#
# station                                                     BEO  \
# Station name                                       BEO Moussala
# Country                                                      BG
# Coordinates, altitude               42 ◦ 10 N,23 ◦ 35 E, 2971 m
# Categorya                                                   NaN
# Instrument                                                 SMPS
# Reference                                 Nojarov et al. (2009)
# Region                                                  Balkans
# Altitude category      High altitude sites (over 1000 m a.s.l.)
# lat                                            42.1666666666667
# lon                                            23.5833333333333
# altitude                                                 2971 m
# noresm_input_format                               23.58e_42.17n
# noresm_output_format                      LON_23.58e_LAT_42.17n
# Alternative_code                                            BEO
#
# station                                                     CMN
# Station name                                       Monte Cimone
# Country                                                      IT
# Coordinates, altitude               44 ◦ 11 N,10 ◦ 41 E, 2165 m
# Categorya                                                   4.0
# Instrument                                                 DMPS
# Reference                                Marinoni et al. (2008)
# Region                                            Mediterranean
# Altitude category      High altitude sites (over 1000 m a.s.l.)
# lat                                            44.1833333333333
# lon                                            10.6833333333333
# altitude                                                 2165 m
# noresm_input_format                               10.68e_44.18n
# noresm_output_format                      LON_10.68e_LAT_44.18n
# Alternative_code                                            CMN
#
# [14 rows x 24 columns]
# Saving CCN6 to /home/ubuntu/mnts/nird/projects//Output_data_OAS-DEV//collocated_ds//NorESM/noSECTv11_ctrl_fbvoc/CCN6_noSECTv11_ctrl_fbvoc_2008-01-01_2008-01-04_hour_locations.nc
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-a8f4b76b316f> in <module>
#      10                            'hour',
#      11                            history_field=history_field)
# ---> 12     a = c.make_station_data_all()
#
# ~/mnts/nird/projects/OAS-DEV/sectional_v2/util/collocate/collocateLONLAToutput.py in make_station_data_all(self)
#     119         for var in vrs:
#     120             print('making station dataset for %s'%var)
# --> 121             self.make_station_da(var, ds=ds)
#     122         return ds
#     123
#
# ~/mnts/nird/projects/OAS-DEV/sectional_v2/util/collocate/collocateLONLAToutput.py in make_station_da(self, var, ds, recalculate)
#     100             print('Saving %s to %s'%(var,fn))
#     101             with ProgressBar():
# --> 102                 results = delayed_obj.compute()
#     103         return da
#     104
#
# /persistent01/miniconda3/envs/env_sec_v2/lib/python3.6/site-packages/dask/base.py in compute(self, **kwargs)
#     163         dask.base.compute
#     164         """
# --> 165         (result,) = compute(self, traverse=False, **kwargs)
#     166         return result
#     167
#
# /persistent01/miniconda3/envs/env_sec_v2/lib/python3.6/site-packages/dask/base.py in compute(*args, **kwargs)
#     434     keys = [x.__dask_keys__() for x in collections]
#     435     postcomputes = [x.__dask_postcompute__() for x in collections]
# --> 436     results = schedule(dsk, keys, **kwargs)
#     437     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     438
#
# /persistent01/miniconda3/envs/env_sec_v2/lib/python3.6/site-packages/distributed/client.py in get(self, dsk, keys, restrictions, loose_restrictions, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2574                     should_rejoin = False
#    2575             try:
# -> 2576                 results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    2577             finally:
#    2578                 for f in futures.values():
#
# /persistent01/miniconda3/envs/env_sec_v2/lib/python3.6/site-packages/distributed/client.py in gather(self, futures, errors, direct, asynchronous)
#    1872                 direct=direct,
#    1873                 local_worker=local_worker,
# -> 1874                 asynchronous=asynchronous,
#    1875             )
#    1876
#
# /persistent01/miniconda3/envs/env_sec_v2/lib/python3.6/site-packages/distributed/client.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     767         else:
#     768             return sync(
# --> 769                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     770             )
#     771
#
# /persistent01/miniconda3/envs/env_sec_v2/lib/python3.6/site-packages/distributed/utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     330     else:
#     331         while not e.is_set():
# --> 332             e.wait(10)
#     333     if error[0]:
#     334         typ, exc, tb = error[0]
#
# /persistent01/miniconda3/envs/env_sec_v2/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /persistent01/miniconda3/envs/env_sec_v2/lib/python3.6/threading.py in wait(self, timeout)
#     297             else:
#     298                 if timeout > 0:
# --> 299                     gotit = waiter.acquire(True, timeout)
#     300                 else:
#     301                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Compute binned dataset

# %%
# Make station N50 etc.
for case_name in cases_sec:
    s = SizedistributionStationBins(case_name, from_t, to_t, [minDiameter, maxDiameter], True, 'hour',
                 nr_bins=nr_of_bins, history_field=history_field)
    s.compute_Nd_vars()

for case_name in cases_orig:
    s = SizedistributionStationBins(case_name, from_t, to_t, [minDiameter, maxDiameter], False, 'hour',
                                    nr_bins=nr_of_bins, history_field=history_field)
    s.compute_Nd_vars()
