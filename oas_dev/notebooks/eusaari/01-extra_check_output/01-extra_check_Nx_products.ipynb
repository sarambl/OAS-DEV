# %%
from useful_scit.imps import *

# %%
from sectional_v2.util.Nd.sizedist_class_v2.SizedistributionBins import SizedistributionStationBins
from sectional_v2.util.Nd.sizedist_class_v2.SizedistributionStation import SizedistributionStation
from sectional_v2.util.collocate.collocateLONLAToutput import CollocateLONLATout
from sectional_v2.constants import sized_varListNorESM, list_sized_vars_noresm, list_sized_vars_nonsec
#from useful_scit.util import log
import useful_scit.util.log as log
import time
log.ger.setLevel(log.log.INFO)
# Out:
# /home/ubuntu/mnts/nird/projects//Output_data_OAS-DEV/
# /home/ubuntu/mnts/nird/projects/OAS-DEV/sectional_v2/data_info/area_defs.csv

# %%
cases_orig =['noSECTv11_noresm2_ricc_oxdiur']#,'noSECTv11_noresm2_ricc_oxdiur','noSECTv11_noresm2_ricc']#, 'noSECTv11_noresm2_ctrl', 'noSECTv11_ctrl_fbvoc']#,'noSECTv11_ctrl']#'noSECTv11_noresm2_NFHIST']#'noSECTv11_ctrl_fbvoc'] #/no SECTv11_ctrl
cases_sec = ['SECTv21_ctrl_koagD']#'SECTv11_noresm2_ctrl', 'SECTv11_ctrl_fbvoc','SECTv11_noresm2_adj','SECTv11_noresm2_eq18']#'SECTv11_noresm2_NFHIST']#'SECTv11_ctrl_fbvoc']#'SECTv11_ctrl']#,'SECTv11_ctrl_fbvoc']#'SECTv11_ctrl']
cases_orig =['noSECTv21_ox_ricc_dd','noSECTv21_default_dd']#, 'noSECTv21_ox_ricc']#'noSECTv11_noresm2_ricc', 'noSECTv11_noresm2_ctrl', 'noSECTv11_ctrl_fbvoc','noSECTv11_ctrl']#'noSECTv11_noresm2_NFHIST']#'noSECTv11_ctrl_fbvoc'] #/no SECTv11_ctrl

# %% [markdown]
# # 2008-2009

# %%
from_t = '2008-01-01'
to_t = '2009-01-01'

# %%
varl=['N250',
      'N30-50',
      'N50',
      'N100']
n_rows = 2
n_cols=2

# %%
#arl=['COAGNUCL','GR','GRSOA','GRH2SO4','NUCLRATE','FORMRATE','SO2', 'SOA_NA','SO4_NA', 'cb_SOA_NA','cb_SO4_NA','H2SO4','SOA_LV','SOA_SV', 'NCONC01','NMR01','SIGMA01']
ds_dic={}
for case_name in cases_sec:
    varlist =varl
    c = CollocateLONLATout(case_name, from_t, to_t,
                           True,
                           'hour')
    a =c.get_station_ds(varlist)
    ds_dic[case_name]=a
    #if c.check_if_load_raw_necessary(varlist ):
    #    a = c.make_station_data_all()
for case_name in cases_orig:
    varlist =varl
    c = CollocateLONLATout(case_name, from_t, to_t,
                           False,
                           'hour')
    a =c.get_station_ds(varlist)
    ds_dic[case_name]=a
# Out:
# /home/ubuntu/mnts/nird/projects//Output_data_OAS-DEV//collocated_ds//NorESM/SECTv21_ctrl_koagD/N250_SECTv21_ctrl_koagD_2008-01-01_2009-01-01_hour_locations.nc
# /home/ubuntu/mnts/nird/projects//Output_data_OAS-DEV//collocated_ds//NorESM/SECTv21_ctrl_koagD/N30-50_SECTv21_ctrl_koagD_2008-01-01_2009-01-01_hour_locations.nc
# /home/ubuntu/mnts/nird/projects//Output_data_OAS-DEV//collocated_ds//NorESM/SECTv21_ctrl_koagD/N50_SECTv21_ctrl_koagD_2008-01-01_2009-01-01_hour_locations.nc
# /home/ubuntu/mnts/nird/projects//Output_data_OAS-DEV//collocated_ds//NorESM/SECTv21_ctrl_koagD/N100_SECTv21_ctrl_koagD_2008-01-01_2009-01-01_hour_locations.nc
# /home/ubuntu/mnts/nird/projects//Output_data_OAS-DEV//collocated_ds//NorESM/noSECTv21_ox_ricc_dd/N250_noSECTv21_ox_ricc_dd_2008-01-01_2009-01-01_hour_locations.nc
# /home/ubuntu/mnts/nird/projects//Output_data_OAS-DEV//collocated_ds//NorESM/noSECTv21_ox_ricc_dd/N30-50_noSECTv21_ox_ricc_dd_2008-01-01_2009-01-01_hour_locations.nc
# /home/ubuntu/mnts/nird/projects//Output_data_OAS-DEV//collocated_ds//NorESM/noSECTv21_ox_ricc_dd/N50_noSECTv21_ox_ricc_dd_2008-01-01_2009-01-01_hour_locations.nc
# /home/ubuntu/mnts/nird/projects//Output_data_OAS-DEV//collocated_ds//NorESM/noSECTv21_ox_ricc_dd/N100_noSECTv21_ox_ricc_dd_2008-01-01_2009-01-01_hour_locations.nc
# /home/ubuntu/mnts/nird/projects//Output_data_OAS-DEV//collocated_ds//NorESM/noSECTv21_default_dd/N250_noSECTv21_default_dd_2008-01-01_2009-01-01_hour_locations.nc
# /home/ubuntu/mnts/nird/projects//Output_data_OAS-DEV//collocated_ds//NorESM/noSECTv21_default_dd/N30-50_noSECTv21_default_dd_2008-01-01_2009-01-01_hour_locations.nc
# /home/ubuntu/mnts/nird/projects//Output_data_OAS-DEV//collocated_ds//NorESM/noSECTv21_default_dd/N50_noSECTv21_default_dd_2008-01-01_2009-01-01_hour_locations.nc
# /home/ubuntu/mnts/nird/projects//Output_data_OAS-DEV//collocated_ds//NorESM/noSECTv21_default_dd/N100_noSECTv21_default_dd_2008-01-01_2009-01-01_hour_locations.nc

# %%
for case in cases_orig+cases_sec:
    fig, axs = plt.subplots(n_rows,n_cols, figsize=[20,20])
    for var, ax in zip(varl, axs.flatten()):
        #_,ax = plt.subplots()
        _da = ds_dic[case].isel(lev=-1)[var]
        for station in _da.station.values:
            _da.sel(station=station).plot(ax=ax)
        ax.set_title(case)
    plt.show()
# Out:
# /persistent01/miniconda3/envs/env_sec_v2/lib/python3.6/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # 2009-2010

# %%
from_t = '2009-01-01'
to_t = '2010-01-01'

# %%
varl=['N250',
      'N30-50',
      'N50',
      'N100']
n_rows = 2
n_cols=2

# %%
#arl=['COAGNUCL','GR','GRSOA','GRH2SO4','NUCLRATE','FORMRATE','SO2', 'SOA_NA','SO4_NA', 'cb_SOA_NA','cb_SO4_NA','H2SO4','SOA_LV','SOA_SV', 'NCONC01','NMR01','SIGMA01']
ds_dic={}
for case_name in cases_sec:
    varlist =varl
    c = CollocateLONLATout(case_name, from_t, to_t,
                           True,
                           'hour')
    a =c.get_station_ds(varlist)
    ds_dic[case_name]=a
    #if c.check_if_load_raw_necessary(varlist ):
    #    a = c.make_station_data_all()
for case_name in cases_orig:
    varlist =varl
    c = CollocateLONLATout(case_name, from_t, to_t,
                           False,
                           'hour')
    a =c.get_station_ds(varlist)
    ds_dic[case_name]=a
# Out:
# /home/ubuntu/mnts/nird/projects//Output_data_OAS-DEV//collocated_ds//NorESM/SECTv21_ctrl_koagD/N250_SECTv21_ctrl_koagD_2009-01-01_2010-01-01_hour_locations.nc
# /home/ubuntu/mnts/nird/projects//Output_data_OAS-DEV//collocated_ds//NorESM/SECTv21_ctrl_koagD/N30-50_SECTv21_ctrl_koagD_2009-01-01_2010-01-01_hour_locations.nc
# /home/ubuntu/mnts/nird/projects//Output_data_OAS-DEV//collocated_ds//NorESM/SECTv21_ctrl_koagD/N50_SECTv21_ctrl_koagD_2009-01-01_2010-01-01_hour_locations.nc
# /home/ubuntu/mnts/nird/projects//Output_data_OAS-DEV//collocated_ds//NorESM/SECTv21_ctrl_koagD/N100_SECTv21_ctrl_koagD_2009-01-01_2010-01-01_hour_locations.nc
# /home/ubuntu/mnts/nird/projects//Output_data_OAS-DEV//collocated_ds//NorESM/noSECTv21_ox_ricc_dd/N250_noSECTv21_ox_ricc_dd_2009-01-01_2010-01-01_hour_locations.nc
# /home/ubuntu/mnts/nird/projects//Output_data_OAS-DEV//collocated_ds//NorESM/noSECTv21_ox_ricc_dd/N30-50_noSECTv21_ox_ricc_dd_2009-01-01_2010-01-01_hour_locations.nc
# /home/ubuntu/mnts/nird/projects//Output_data_OAS-DEV//collocated_ds//NorESM/noSECTv21_ox_ricc_dd/N50_noSECTv21_ox_ricc_dd_2009-01-01_2010-01-01_hour_locations.nc
# /home/ubuntu/mnts/nird/projects//Output_data_OAS-DEV//collocated_ds//NorESM/noSECTv21_ox_ricc_dd/N100_noSECTv21_ox_ricc_dd_2009-01-01_2010-01-01_hour_locations.nc
# /home/ubuntu/mnts/nird/projects//Output_data_OAS-DEV//collocated_ds//NorESM/noSECTv21_default_dd/N250_noSECTv21_default_dd_2009-01-01_2010-01-01_hour_locations.nc
# /home/ubuntu/mnts/nird/projects//Output_data_OAS-DEV//collocated_ds//NorESM/noSECTv21_default_dd/N30-50_noSECTv21_default_dd_2009-01-01_2010-01-01_hour_locations.nc
# /home/ubuntu/mnts/nird/projects//Output_data_OAS-DEV//collocated_ds//NorESM/noSECTv21_default_dd/N50_noSECTv21_default_dd_2009-01-01_2010-01-01_hour_locations.nc
# /home/ubuntu/mnts/nird/projects//Output_data_OAS-DEV//collocated_ds//NorESM/noSECTv21_default_dd/N100_noSECTv21_default_dd_2009-01-01_2010-01-01_hour_locations.nc

# %%
for case in cases_orig+cases_sec:
    fig, axs = plt.subplots(n_rows,n_cols, figsize=[20,20])
    for var, ax in zip(varl, axs.flatten()):
        #_,ax = plt.subplots()
        _da = ds_dic[case].isel(lev=-1)[var]
        for station in _da.station.values:
            _da.sel(station=station).plot(ax=ax)
        ax.set_title(case)
    plt.show()
